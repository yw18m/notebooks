# %%
import spss.pyspark.runtime
from pyspark.sql.types import *
#asContext = spss.pyspark.runtime.getContext()
#sparkContext = asc.getSparkContext()

try:
    import sys
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", 'sys'])
finally:
    import sys

try:
    import subprocess
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", 'subprocess'])
finally:
    import subprocess
    
subprocess.check_call([sys.executable, "-m", "pip", "install", '--upgrade', 'pip'])

try:
    import ibm_watson
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", 'ibm-watson'])
finally:
    import ibm_watson
    
try:
    import ibm_cloud_sdk_core
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", 'ibm-cloud-sdk-core"'])
finally:
    import ibm_cloud_sdk_core
    
try:
    import json
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", 'json'])
finally:
    import json

from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Test 1 single string translation
#to_translate = %%dlgTranslateField%%
#api_key = %%dlgAPIKey%%
#api_url = %%dlgAPIUrl%%

# Hello world in French
to_translate = "Bonjour le monde"
api_key = ""
api_url = ""

authenticator = IAMAuthenticator(api_key)
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

language_translator.set_service_url(api_url)
translation = language_translator.translate(
    text=to_translate,
    model_id='fr-en').get_result()
    
translated_result = json.loads(json.dumps(translation, indent=2, ensure_ascii=False))['translations'][0]['translation']
print("Test case 1 result: " + translated_result)

# Test 2 upload a file
#file_uploaded = dlgFileUpload
